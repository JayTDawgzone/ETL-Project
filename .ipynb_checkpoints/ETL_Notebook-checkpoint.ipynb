# %%
import warnings
warnings.filterwarnings('ignore')
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine
from sqlalchemy import func, Table, Column, Integer, String, MetaData
from sqlite3 import Error
import sqlite3

# %% [markdown]
# ## Create and Connect to Sqlite Database

# %%
sqlite_file = 'pokemon_db.sqlite'
# Connecting to the database file

# %% [markdown]
# ## Extracting Trading Card Game Data

# %%
from pokemontcgsdk import Card
from pokemontcgsdk import Set
from pokemontcgsdk import Type
from pokemontcgsdk import Supertype
from pokemontcgsdk import Subtype

# %%
import pandas as pd
import numpy as np

# %%
# Retreive Card Data (This will take a while)
cards = Card.all()

# %%
#Pull card information into lists.

x = 0
card_name = []
card_id = []
national_pokedex_number = []
image_url = []
image_url_hi_res = []
card_subtype = []
card_ability = []
card_ancient_trait = []
card_hp = []
card_number = []
card_artist = []
card_rarity = []
card_series = []
card_set = []
card_set_code = []
card_converted_retreat_cost = []
card_text = []
card_types = []
card_attacks = []
card_weaknesses = []
card_resistances = []
card_evolves_from = []
for row in cards:
    card_id.append(row.id)
    card_name.append(row.name)
    national_pokedex_number.append(row.national_pokedex_number)
    image_url.append(row.image_url)
    image_url_hi_res.append(row.image_url_hi_res)
    card_subtype.append(row.subtype)
    card_ability.append(row.ability)
    card_ancient_trait.append(row.ancient_trait)
    card_hp.append(row.hp)
    card_number.append(row.number)
    card_artist.append(row.artist)
    card_rarity.append(row.rarity)
    card_series.append(row.series)
    card_set.append(row.set)
    card_set_code.append(row.set_code)
    card_converted_retreat_cost.append(row.converted_retreat_cost)
    card_text.append(row.text)
    card_types.append(row.types)
    card_attacks.append(row.attacks)
    card_weaknesses.append(row.weaknesses)
    card_resistances.append(row.resistances)
    card_evolves_from.append(row.evolves_from)
#     x = x + 1
#     if x == 5:
#         break

# %%
#Convert list to pandas DataFrame
pokemon_cards = pd.DataFrame({
    'card_name':card_name,
    'card_id':card_id,
    'national_pokedex_number':national_pokedex_number,
    'image_url':image_url,
    'image_url_hi_res':image_url_hi_res,
    'card_subtype':card_subtype,
    'card_ability':card_ability,
    'card_ancient_trait':card_ancient_trait,
    'card_hp':card_hp,
    'card_number':card_number,
    'card_artist':card_artist,
    'card_rarity':card_rarity,
    'card_series':card_series,
    'card_set':card_set,
    'card_set_code':card_set_code,
    'card_converted_retreat_cost':card_converted_retreat_cost,
    'card_text':card_text,
    'card_types':card_types,
    'card_attacks':card_attacks,
    'card_weaknesses':card_weaknesses,
    'card_resistances':card_resistances,
    'card_evolves_from':card_evolves_from
})

pokemon_cards.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11901 entries, 0 to 11900
# Data columns (total 22 columns):
# card_name                      11901 non-null object
# card_id                        11901 non-null object
# national_pokedex_number        10078 non-null float64
# image_url                      11901 non-null object
# image_url_hi_res               11901 non-null object
# card_subtype                   11896 non-null object
# card_ability                   2393 non-null object
# card_ancient_trait             39 non-null object
# card_hp                        10380 non-null object
# card_number                    11901 non-null object
# card_artist                    11787 non-null object
# card_rarity                    11639 non-null object
# card_series                    11901 non-null object
# card_set                       11901 non-null object
# card_set_code                  11901 non-null object
# card_converted_retreat_cost    9964 non-null float64
# card_text                      2923 non-null object
# card_types                     10091 non-null object
# card_attacks                   10055 non-null object
# card_weaknesses                9807 non-null object
# card_resistances               3318 non-null object
# card_evolves_from              4266 non-null object
# dtypes: float64(2), object(20)
# memory usage: 2.0+ MB

# %%
#Preview DataFrame
pokemon_cards.head()

# %% [markdown]
# ### Cleaning Up Trading Card Data

# %%
#Drop any NaN values from ['national_pokedex_number']
pokemon_cards = pokemon_cards[np.isfinite(pokemon_cards['national_pokedex_number'])]

# %%
#Set Column Types to Strings to avoid import errors later
pokemon_cards['card_types'] = pokemon_cards['card_types'].astype(str)
pokemon_cards['card_attacks'] = pokemon_cards['card_attacks'].astype(str)
pokemon_cards['card_weaknesses'] = pokemon_cards['card_weaknesses'].astype(str)
pokemon_cards['card_resistances'] = pokemon_cards['card_resistances'].astype(str)
pokemon_cards['card_evolves_from'] = pokemon_cards['card_evolves_from'].astype(str)
pokemon_cards['card_artist'] = pokemon_cards['card_artist'].astype(str)
pokemon_cards['card_ancient_trait'] = pokemon_cards['card_ancient_trait'].astype(str)
pokemon_cards['card_ability'] = pokemon_cards['card_ability'].astype(str)
pokemon_cards['card_text'] = pokemon_cards['card_ability'].astype(str)

# %% [markdown]
# ## Extracting Pokemon Console Game Data

# %%
#Retreive a list of unique Pokedex ids
unique_pokedex_number = [] 
for i in national_pokedex_number: 
    if i not in unique_pokedex_number: 
        unique_pokedex_number.append(i) 
    if i == 'None':
        pass

# Remove the None Value
unique_pokedex_number.pop(1)
#Remove the last 7 Pokedex numbers (They don't exist in the bulbapedia data yet)
unique_pokedex_number = unique_pokedex_number[:len(unique_pokedex_number)-7]

# %%
import requests
import json

base_url = 'https://pokeapi.co/api/v2/'
bulbapedia = pd.DataFrame({'pokedex_id': unique_pokedex_number})
x = 0
# itterate through rows and find the bulbapedia stats for each pokemon by national pokedex id.
for index, row in bulbapedia.iterrows():
    poke_id = str(round(row['pokedex_id']))
#     x = x + 1
#     if x == 10:
#         break
    query_url = base_url + '/pokemon/' + poke_id + '/'
    response = requests.get(query_url)
    response_json = response.json()
    json_dump = json.dumps(response_json,indent=1)
    

# create a new data frame with bulbapedia entries.
    try:
        bulbapedia.loc[index, "sprite"] = response_json['sprites']['front_default']
        bulbapedia.loc[index, "pokemon_name"] = response_json["name"]
        bulbapedia.loc[index, "pokemon_weight"] = response_json['weight']
        bulbapedia.loc[index, "pokemon_height"] = response_json['height']
        bulbapedia.loc[index, "speed"] = response_json["stats"][0]['base_stat']
        bulbapedia.loc[index, "special_defense"] = response_json["stats"][1]['base_stat']
        bulbapedia.loc[index, "special_attack"] = response_json["stats"][2]['base_stat']
        bulbapedia.loc[index, "defense"] = response_json["stats"][3]['base_stat']
        bulbapedia.loc[index, "attack"] = response_json["stats"][4]['base_stat']
        bulbapedia.loc[index, "hp"] = response_json["stats"][5]['base_stat']
        bulbapedia.loc[index, "pokemon_type1"] = response_json["types"][0]['type']['name']
        bulbapedia.loc[index, "pokemon_type2"] = response_json["types"][1]['type']['name']
        

    except (KeyError, IndexError, ValueError, json.JSONDecodeError):
        print(f'{poke_id} Could not find one or more Element')
# Out:
# 104 Could not find one or more Element
# 387 Could not find one or more Element
# 182 Could not find one or more Element
# 297 Could not find one or more Element
# 716 Could not find one or more Element
# 200 Could not find one or more Element
# 692 Could not find one or more Element
# 262 Could not find one or more Element
# 204 Could not find one or more Element
# 362 Could not find one or more Element
# 181 Could not find one or more Element
# 126 Could not find one or more Element
# 4 Could not find one or more Element
# 477 Could not find one or more Element
# 684 Could not find one or more Element
# 143 Could not find one or more Element
# 261 Could not find one or more Element
# 466 Could not find one or more Element
# 201 Could not find one or more Element
# 301 Could not find one or more Element
# 300 Could not find one or more Element
# 399 Could not find one or more Element
# 659 Could not find one or more Element
# 405 Could not find one or more Element
# 455 Could not find one or more Element
# 59 Could not find one or more Element
# 36 Could not find one or more Element
# 470 Could not find one or more Element
# 490 Could not find one or more Element
# 386 Could not find one or more Element
# 588 Could not find one or more Element
# 105 Could not find one or more Element
# 50 Could not find one or more Element
# 196 Could not find one or more Element
# 96 Could not find one or more Element
# 109 Could not find one or more Element
# 136 Could not find one or more Element
# 288 Could not find one or more Element
# 383 Could not find one or more Element
# 356 Could not find one or more Element
# 331 Could not find one or more Element
# 289 Could not find one or more Element
# 616 Could not find one or more Element
# 108 Could not find one or more Element
# 135 Could not find one or more Element
# 621 Could not find one or more Element
# 243 Could not find one or more Element
# 603 Could not find one or more Element
# 563 Could not find one or more Element
# 419 Could not find one or more Element
# 33 Could not find one or more Element
# 273 Could not find one or more Element
# 467 Could not find one or more Element
# 287 Could not find one or more Element
# 428 Could not find one or more Element
# 497 Could not find one or more Element
# 361 Could not find one or more Element
# 68 Could not find one or more Element
# 255 Could not find one or more Element
# 54 Could not find one or more Element
# 570 Could not find one or more Element
# 328 Could not find one or more Element
# 37 Could not find one or more Element
# 446 Could not find one or more Element
# 600 Could not find one or more Element
# 57 Could not find one or more Element
# 601 Could not find one or more Element
# 641 Could not find one or more Element
# 244 Could not find one or more Element
# 417 Could not find one or more Element
# 359 Could not find one or more Element
# 440 Could not find one or more Element
# 447 Could not find one or more Element
# 89 Could not find one or more Element
# 132 Could not find one or more Element
# 341 Could not find one or more Element
# 309 Could not find one or more Element
# 118 Could not find one or more Element
# 572 Could not find one or more Element
# 218 Could not find one or more Element
# 185 Could not find one or more Element
# 265 Could not find one or more Element
# 360 Could not find one or more Element
# 449 Could not find one or more Element
# 599 Could not find one or more Element
# 11 Could not find one or more Element
# 133 Could not find one or more Element
# 67 Could not find one or more Element
# 117 Could not find one or more Element
# 88 Could not find one or more Element
# 9 Could not find one or more Element
# 114 Could not find one or more Element
# 394 Could not find one or more Element
# 110 Could not find one or more Element
# 465 Could not find one or more Element
# 116 Could not find one or more Element
# 119 Could not find one or more Element
# 148 Could not find one or more Element
# 20 Could not find one or more Element
# 266 Could not find one or more Element
# 120 Could not find one or more Element
# 159 Could not find one or more Element
# 78 Could not find one or more Element
# 371 Could not find one or more Element
# 180 Could not find one or more Element
# 147 Could not find one or more Element
# 418 Could not find one or more Element
# 100 Could not find one or more Element
# 173 Could not find one or more Element
# 63 Could not find one or more Element
# 134 Could not find one or more Element
# 125 Could not find one or more Element
# 240 Could not find one or more Element
# 27 Could not find one or more Element
# 86 Could not find one or more Element
# 602 Could not find one or more Element
# 610 Could not find one or more Element
# 77 Could not find one or more Element
# 612 Could not find one or more Element
# 155 Could not find one or more Element
# 58 Could not find one or more Element
# 326 Could not find one or more Element
# 106 Could not find one or more Element
# 310 Could not find one or more Element
# 481 Could not find one or more Element
# 312 Could not find one or more Element
# 107 Could not find one or more Element
# 311 Could not find one or more Element
# 382 Could not find one or more Element
# 285 Could not find one or more Element
# 66 Could not find one or more Element
# 725 Could not find one or more Element
# 209 Could not find one or more Element
# 216 Could not find one or more Element
# 158 Could not find one or more Element
# 7 Could not find one or more Element
# 349 Could not find one or more Element
# 26 Could not find one or more Element
# 154 Could not find one or more Element
# 25 Could not find one or more Element
# 179 Could not find one or more Element
# 258 Could not find one or more Element
# 429 Could not find one or more Element
# 38 Could not find one or more Element
# 325 Could not find one or more Element
# 314 Could not find one or more Element
# 241 Could not find one or more Element
# 651 Could not find one or more Element
# 157 Could not find one or more Element
# 24 Could not find one or more Element
# 665 Could not find one or more Element
# 252 Could not find one or more Element
# 672 Could not find one or more Element
# 101 Could not find one or more Element
# 673 Could not find one or more Element
# 153 Could not find one or more Element
# 654 Could not find one or more Element
# 30 Could not find one or more Element
# 5 Could not find one or more Element
# 388 Could not find one or more Element
# 197 Could not find one or more Element
# 427 Could not find one or more Element
# 492 Could not find one or more Element
# 390 Could not find one or more Element
# 245 Could not find one or more Element
# 568 Could not find one or more Element
# 393 Could not find one or more Element
# 233 Could not find one or more Element
# 32 Could not find one or more Element
# 729 Could not find one or more Element
# 295 Could not find one or more Element
# 683 Could not find one or more Element
# 656 Could not find one or more Element
# 128 Could not find one or more Element
# 657 Could not find one or more Element
# 137 Could not find one or more Element
# 504 Could not find one or more Element
# 253 Could not find one or more Element
# 217 Could not find one or more Element
# 264 Could not find one or more Element
# 293 Could not find one or more Element
# 160 Could not find one or more Element
# 511 Could not find one or more Element
# 548 Could not find one or more Element
# 498 Could not find one or more Element
# 611 Could not find one or more Element
# 23 Could not find one or more Element
# 516 Could not find one or more Element
# 550 Could not find one or more Element
# 52 Could not find one or more Element
# 53 Could not find one or more Element
# 350 Could not find one or more Element
# 324 Could not find one or more Element
# 29 Could not find one or more Element
# 127 Could not find one or more Element
# 299 Could not find one or more Element
# 789 Could not find one or more Element
# 97 Could not find one or more Element
# 8 Could not find one or more Element
# 150 Could not find one or more Element
# 377 Could not find one or more Element
# 151 Could not find one or more Element
# 379 Could not find one or more Element
# 736 Could not find one or more Element
# 152 Could not find one or more Element
# 239 Could not find one or more Element
# 56 Could not find one or more Element
# 529 Could not find one or more Element
# 317 Could not find one or more Element
# 482 Could not find one or more Element
# 486 Could not find one or more Element
# 51 Could not find one or more Element
# 372 Could not find one or more Element
# 129 Could not find one or more Element
# 512 Could not find one or more Element
# 674 Could not find one or more Element
# 237 Could not find one or more Element
# 420 Could not find one or more Element
# 61 Could not find one or more Element
# 55 Could not find one or more Element
# 190 Could not find one or more Element
# 113 Could not find one or more Element
# 495 Could not find one or more Element
# 762 Could not find one or more Element
# 501 Could not find one or more Element
# 321 Could not find one or more Element
# 99 Could not find one or more Element
# 615 Could not find one or more Element
# 489 Could not find one or more Element
# 503 Could not find one or more Element
# 535 Could not find one or more Element
# 60 Could not find one or more Element
# 172 Could not find one or more Element
# 575 Could not find one or more Element
# 577 Could not find one or more Element
# 403 Could not find one or more Element
# 523 Could not find one or more Element
# 254 Could not find one or more Element
# 513 Could not find one or more Element
# 653 Could not find one or more Element
# 525 Could not find one or more Element
# 268 Could not find one or more Element
# 526 Could not find one or more Element
# 538 Could not find one or more Element
# 488 Could not find one or more Element
# 556 Could not find one or more Element
# 539 Could not find one or more Element
# 574 Could not find one or more Element
# 576 Could not find one or more Element
# 28 Could not find one or more Element
# 35 Could not find one or more Element
# 531 Could not find one or more Element
# 296 Could not find one or more Element
# 206 Could not find one or more Element
# 412 Could not find one or more Element
# 19 Could not find one or more Element
# 626 Could not find one or more Element
# 336 Could not find one or more Element
# 355 Could not find one or more Element
# 316 Could not find one or more Element
# 313 Could not find one or more Element
# 115 Could not find one or more Element
# 517 Could not find one or more Element
# 263 Could not find one or more Element
# 98 Could not find one or more Element
# 370 Could not find one or more Element
# 669 Could not find one or more Element
# 161 Could not find one or more Element
# 505 Could not find one or more Element
# 554 Could not find one or more Element
# 493 Could not find one or more Element
# 619 Could not find one or more Element
# 555 Could not find one or more Element
# 515 Could not find one or more Element
# 514 Could not find one or more Element
# 584 Could not find one or more Element
# 562 Could not find one or more Element
# 335 Could not find one or more Element
# 803 Could not find one or more Element
# 579 Could not find one or more Element
# 613 Could not find one or more Element
# 402 Could not find one or more Element
# 210 Could not find one or more Element
# 676 Could not find one or more Element
# 192 Could not find one or more Element
# 594 Could not find one or more Element
# 509 Could not find one or more Element
# 368 Could not find one or more Element
# 367 Could not find one or more Element
# 202 Could not find one or more Element
# 571 Could not find one or more Element
# 320 Could not find one or more Element
# 573 Could not find one or more Element
# 352 Could not find one or more Element
# 236 Could not find one or more Element
# 354 Could not find one or more Element
# 366 Could not find one or more Element
# 231 Could not find one or more Element
# 507 Could not find one or more Element
# 532 Could not find one or more Element
# 491 Could not find one or more Element
# 353 Could not find one or more Element
# 65 Could not find one or more Element
# 378 Could not find one or more Element
# 508 Could not find one or more Element
# 522 Could not find one or more Element
# 614 Could not find one or more Element
# 175 Could not find one or more Element
# 224 Could not find one or more Element
# 223 Could not find one or more Element
# 549 Could not find one or more Element
# 620 Could not find one or more Element
# 617 Could not find one or more Element
# 582 Could not find one or more Element
# 583 Could not find one or more Element
# 605 Could not find one or more Element
# 533 Could not find one or more Element
# 162 Could not find one or more Element
# 90 Could not find one or more Element
# 518 Could not find one or more Element
# 294 Could not find one or more Element
# 704 Could not find one or more Element
# 232 Could not find one or more Element
# 351 Could not find one or more Element
# 664 Could not find one or more Element
# 404 Could not find one or more Element
# 534 Could not find one or more Element
# 422 Could not find one or more Element
# 685 Could not find one or more Element
# 156 Could not find one or more Element
# 191 Could not find one or more Element
# 450 Could not find one or more Element
# 10 Could not find one or more Element
# 496 Could not find one or more Element
# 790 Could not find one or more Element
# 480 Could not find one or more Element
# 471 Could not find one or more Element
# 726 Could not find one or more Element
# 502 Could not find one or more Element
# 578 Could not find one or more Element
# 771 Could not find one or more Element
# 569 Could not find one or more Element
# 606 Could not find one or more Element
# 327 Could not find one or more Element
# 650 Could not find one or more Element
# 506 Could not find one or more Element
# 474 Could not find one or more Element
# 807 Could not find one or more Element
# 693 Could not find one or more Element
# 671 Could not find one or more Element
# 424 Could not find one or more Element
# 700 Could not find one or more Element
# 677 Could not find one or more Element
# 678 Could not find one or more Element
# 739 Could not find one or more Element
# 463 Could not find one or more Element
# 431 Could not find one or more Element
# 421 Could not find one or more Element
# 433 Could not find one or more Element
# 682 Could not find one or more Element
# 670 Could not find one or more Element
# 432 Could not find one or more Element
# 745 Could not find one or more Element
# 401 Could not find one or more Element
# 242 Could not find one or more Element
# 457 Could not find one or more Element
# 358 Could not find one or more Element
# 712 Could not find one or more Element
# 409 Could not find one or more Element
# 408 Could not find one or more Element
# 456 Could not find one or more Element
# 510 Could not find one or more Element
# 186 Could not find one or more Element
# 631 Could not find one or more Element
# 713 Could not find one or more Element
# 744 Could not find one or more Element
# 524 Could not find one or more Element
# 235 Could not find one or more Element
# 705 Could not find one or more Element
# 800 Could not find one or more Element
# 754 Could not find one or more Element
# 763 Could not find one or more Element
# 728 Could not find one or more Element
# 64 Could not find one or more Element
# 773 Could not find one or more Element
# 234 Could not find one or more Element
# 735 Could not find one or more Element
# 438 Could not find one or more Element
# 706 Could not find one or more Element
# 604 Could not find one or more Element
# 753 Could not find one or more Element
# 734 Could not find one or more Element
# 772 Could not find one or more Element
# 746 Could not find one or more Element
# 782 Could not find one or more Element
# 775 Could not find one or more Element
# 796 Could not find one or more Element

# %%
#Preview Json
response_json

# %%
#Preview Data Frame

#Set Max Column Width to Store Sprites Properly
pd.set_option('display.max_colwidth', -1)

#Sort by Pokedex ID
bulbapedia = bulbapedia.sort_values('pokedex_id')

# %%
species_url = 'https://pokeapi.co/api/v2/pokemon-species/'
x = 0
# itterate through rows and find the bulbapedia stats for each pokemon by national pokedex id.
for index, row in bulbapedia.iterrows():
    poke_id = str(round(row['pokedex_id']))
    query_url = species_url + poke_id + '/'
    response = requests.get(query_url)
    response_json = response.json()
    json_dump = json.dumps(response_json,indent=1)
    

#create a new data frame with bulbapedia entries.
    try:
        bulbapedia.loc[index, "base_hapiness"] = response_json["base_happiness"]
        bulbapedia.loc[index, "color_group"] = response_json['color']['name']
        bulbapedia.loc[index, "egg_group"] = response_json['egg_groups'][0]['name']
        bulbapedia.loc[index, "generation"] = response_json["generation"]['name']
        bulbapedia.loc[index, "shape"] = response_json["shape"]['name']
        

    except (KeyError, IndexError, ValueError, json.JSONDecodeError):
        print(f'{poke_id} One or More Element Not Found')

# %%
def create_connection(db_file):
    conn = None
    try:
        conn = sqlite3.connect(db_file)
        return conn
    except Error as e:
        print(e)
 
    return conn



 
def create_table(conn, create_table_sql):
    try:
        c = conn.cursor()
        c.execute(create_table_sql)
    except Error as e:
        print(e)
 
 
def main():
    database = sqlite_file
 
    sql_create_game_table = """ CREATE TABLE IF NOT EXISTS game4 (
                                        pokedex_id integer PRIMARY KEY,
                                        sprite text,
                                        pokemon_name text,
                                        pokemon_weight float,
                                        pokemon_height float,
                                        speed float,
                                        special_defense float,
                                        special_attack float,
                                        defense float,
                                        attack float,
                                        hp float,
                                        pokemon_type1 text,
                                        pokemon_type2 text,
                                        base_hapiness float,
                                        color_group text,
                                        egg_group text,
                                        generation text,
                                        shape text
                                    ); """
 
    sql_create_card_table = """CREATE TABLE IF NOT EXISTS cards4 (
                                    card_name text NOT NULL,
                                    card_id varchar(20) PRIMARY KEY,
                                    national_pokedex_number int,
                                    image_url text,
                                    image_url_hi_res text,
                                    card_subtype text,
                                    card_ability text,
                                    card_ancient_trait text,
                                    card_hp int,
                                    card_number int,
                                    card_artist text,
                                    card_rarity text,
                                    card_series text,
                                    card_set text,
                                    card_set_code text,
                                    card_retreat_cost,
                                    card_text text,
                                    card_types text,
                                    card_attacks text,
                                    card_weaknesses text,
                                    card_evolves_from text,   
                                    FOREIGN KEY (national_pokedex_number) REFERENCES bulbapedia (pokedex_id)
                                );"""
    # create a database connection
    conn = create_connection(database)
 
    # create tables
    if conn is not None:
        # create projects table
        create_table(conn, sql_create_game_table)
        print("Connection Made")
        # create tasks table
        create_table(conn, sql_create_card_table)
    else:
        print("Error! cannot create the database connection.")
 
 
if __name__ == '__main__':
    main()
# Out:
# Connection Made

# %%
bulbapedia = bulbapedia.set_index('pokedex_id')

# %%
conn = sqlite3.connect(sqlite_file)
c = conn.cursor()
bulbapedia.to_sql('game4', con=conn, if_exists='replace')
pokemon_cards.to_sql('cards4', con=conn, if_exists='replace')
